# %% [markdown]
# <a href="https://colab.research.google.com/github/cathdong66-lgtm/EMSC2010-W9-L1/blob/main/emsc2010_w9_l1_nb1_u7919006.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB1
# Model Earth's surface temperature (in Kelvin) using a zero-dimensional energy balance model without an atmosphere.
#
# $T_e = \left[ \frac{S}{4 \alpha} (1-A)\right]^{1/4}$
#
# where:
# * $T_e$ is Earth's surface temperature in Kelvin
# * $S$ is the solar flux (1366 W/m$^2$)
# * $A$ is albedo (currently around 0.3)
# * $\alpha$ is the Stefan-Boltmann constant (5.67E-8 W/m$^2$/K$^4$)

# %%
S = 1366
A = 0.3
Stefan_Boltzmann = 5.67E-8

# %%
T_e = ((S/(4*Stefan_Boltzmann))*(1-A))**(1/4)
print(T_e)
# Out:
# 254.81584054796193
